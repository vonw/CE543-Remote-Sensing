# %% [markdown]
# # Effect of Aerosols in a Tropical Atmosphere

# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ds = ['/Users/vonw/work/courses/2019-2020/fall/CE543/CE543-Remote-Sensing/RRTM/aerosols/AOD0.00/',
      '/Users/vonw/work/courses/2019-2020/fall/CE543/CE543-Remote-Sensing/RRTM/aerosols/AOD0.25/',
      '/Users/vonw/work/courses/2019-2020/fall/CE543/CE543-Remote-Sensing/RRTM/aerosols/AOD0.50/',
      '/Users/vonw/work/courses/2019-2020/fall/CE543/CE543-Remote-Sensing/RRTM/aerosols/AOD0.75/',
      '/Users/vonw/work/courses/2019-2020/fall/CE543/CE543-Remote-Sensing/RRTM/aerosols/AOD1.00/']

# %%
names = ['level', 'pressure', 'UpwardFlux', 'DifDownFlux', 'DirDownFlux', 'DownwardFlux', 'NetFlux', 'HeatingRate']
aod0_00 = pd.DataFrame(loadtxt(ds[0]+'OUTPUT_RRTM'), columns=names)
aod0_25 = pd.DataFrame(loadtxt(ds[1]+'OUTPUT_RRTM'), columns=names)
aod0_50 = pd.DataFrame(loadtxt(ds[2]+'OUTPUT_RRTM'), columns=names)
aod0_75 = pd.DataFrame(loadtxt(ds[3]+'OUTPUT_RRTM'), columns=names)
aod1_00 = pd.DataFrame(loadtxt(ds[4]+'OUTPUT_RRTM'), columns=names)

# %%
aod0_00
# Out:
#     level    pressure  UpwardFlux  DifDownFlux  DirDownFlux  DownwardFlux  \
# 0    13.0     0.06485    130.5739       0.0000     684.6693      684.6693
# 1    12.0     1.17000    130.5455       0.1116     681.2199      681.3315
# 2    11.0    21.57000    130.9357       1.8737     665.3021      667.1758
# 3    10.0   102.00000    129.0469       8.3051     648.4162      656.7213
# 4     9.0   245.00000    123.5407      18.4895     626.7476      645.2371
# 5     8.0   375.50000    118.3510      26.4081     597.2780      623.6862
# 6     7.0   489.90000    113.7939      32.4190     567.1216      599.5405
# 7     6.0   630.70000    108.2966      38.7626     529.6977      568.4603
# 8     5.0   712.40000    105.2327      41.9513     508.5467      550.4979
# 9     4.0   802.90000    102.1160      45.0676     484.0072      529.0748
# 10    3.0   851.70000    100.6047      46.5777     470.9183      517.4960
# 11    2.0   902.90000     99.1429      48.0485     458.1753      506.2238
# 12    1.0   956.70000     97.8087      49.4640     445.6096      495.0736
# 13    0.0  1013.00000     96.7839      50.8010     433.1184      483.9193
#
#        NetFlux  HeatingRate
# 0   554.095455      0.00000
# 1   550.786005     25.26587
# 2   536.240096      6.01799
# 3   527.674465      0.89873
# 4   521.696476      0.35284
# 5   505.335220      1.05814
# 6   485.746582      1.44477
# 7   460.163709      1.53289
# 8   445.265255      1.53928
# 9   426.958743      1.70735
# 10  416.891318      1.74112
# 11  407.080875      1.61538
# 12  397.264905      1.54162
# 13  387.135458      1.51778

# %%
aod0_25
# Out:
#     level    pressure  UpwardFlux  DifDownFlux  DirDownFlux  DownwardFlux  \
# 0    13.0     0.06485    128.0934       0.0000     684.6693      684.6693
# 1    12.0     1.17000    128.0651       0.1115     681.2199      681.3314
# 2    11.0    21.57000    128.4603       1.8716     665.3021      667.1737
# 3    10.0   102.00000    126.5729       8.2968     648.4162      656.7130
# 4     9.0   245.00000    121.0624      18.4755     626.7476      645.2231
# 5     8.0   375.50000    115.8756      26.3961     597.2780      623.6741
# 6     7.0   489.90000    111.3283      32.4154     567.1216      599.5369
# 7     6.0   630.70000    105.8563      38.7808     529.6977      568.4785
# 8     5.0   712.40000    102.8168      41.9892     508.5467      550.5358
# 9     4.0   802.90000     99.7421      45.1354     484.0072      529.1426
# 10    3.0   851.70000     98.2641      46.6660     470.9183      517.5843
# 11    2.0   902.90000     96.8497      48.1625     458.1753      506.3378
# 12    1.0   956.70000     95.5957      49.6096     445.6096      495.2192
# 13    0.0  1013.00000     87.3843      91.1823     345.7393      436.9215
#
#        NetFlux  HeatingRate
# 0   556.575903      0.00000
# 1   553.266310     25.26697
# 2   538.713343      6.02091
# 3   530.140162      0.89952
# 4   524.160745      0.35292
# 5   507.798547      1.05820
# 6   488.208649      1.44487
# 7   462.622164      1.53311
# 8   447.719061      1.53976
# 9   429.400476      1.70847
# 10  419.320280      1.74333
# 11  409.488041      1.61897
# 12  399.623473      1.54925
# 13  349.537236      7.50486

# %%
figure(figsize=(12,8))
semilogy(aod0_00.UpwardFlux, aod0_00.pressure,
     aod0_25.UpwardFlux, aod0_25.pressure,
     aod0_50.UpwardFlux, aod0_50.pressure,
     aod0_75.UpwardFlux, aod0_75.pressure,
     aod1_00.UpwardFlux, aod1_00.pressure)
gca().invert_yaxis()
xlabel('Flux (W m-2)')
ylabel('Pressure (mb)')
title('Upward Flux')
legend(['0.0', '0.25', '0.5', '0.75', '1.0'], loc='best')

# %%
figure(figsize=(12,8))
plot(aod0_00.DownwardFlux, aod0_00.pressure,
     aod0_25.DownwardFlux, aod0_25.pressure,
     aod0_50.DownwardFlux, aod0_50.pressure,
     aod0_75.DownwardFlux, aod0_75.pressure,
     aod1_00.DownwardFlux, aod1_00.pressure)
gca().invert_yaxis()
xlabel('Flux (W m-2)')
ylabel('Pressure (mb)')
title('Downward Flux')
legend(['0.0', '0.25', '0.5', '0.75', '1.0'], loc='best')

# %%
figure(figsize=(12,8))
plot(aod0_00.DirDownFlux, aod0_00.pressure,
     aod0_25.DirDownFlux, aod0_25.pressure,
     aod0_50.DirDownFlux, aod0_50.pressure,
     aod0_75.DirDownFlux, aod0_75.pressure,
     aod1_00.DirDownFlux, aod1_00.pressure)
gca().invert_yaxis()
xlabel('Flux (W m-2)')
ylabel('Pressure (mb)')
title('Direct Downward Flux')
legend(['0.0', '0.25', '0.5', '0.75', '1.0'], loc='best')

# %%
figure(figsize=(12,8))
plot(aod0_00.DifDownFlux, aod0_00.pressure,
     aod0_25.DifDownFlux, aod0_25.pressure,
     aod0_50.DifDownFlux, aod0_50.pressure,
     aod0_75.DifDownFlux, aod0_75.pressure,
     aod1_00.DifDownFlux, aod1_00.pressure)
gca().invert_yaxis()
xlabel('Flux (W m-2)')
ylabel('Pressure (mb)')
title('Diffuse Downward Flux')
legend(['0.0', '0.25', '0.5', '0.75', '1.0'], loc='best')

# %%
figure(figsize=(12,8))
plot(aod0_00.NetFlux, aod0_00.pressure,
     aod0_25.NetFlux, aod0_25.pressure,
     aod0_50.NetFlux, aod0_50.pressure,
     aod0_75.NetFlux, aod0_75.pressure,
     aod1_00.NetFlux, aod1_00.pressure)
gca().invert_yaxis()
xlabel('Flux (W m-2)')
ylabel('Pressure (mb)')
title('Net Flux')
legend(['0.0', '0.25', '0.5', '0.75', '1.0'], loc='best')

# %%
figure(figsize=(12,8))
plot(aod0_00.HeatingRate, aod0_00.pressure,
     aod0_25.HeatingRate, aod0_25.pressure,
     aod0_50.HeatingRate, aod0_50.pressure,
     aod0_75.HeatingRate, aod0_75.pressure,
     aod1_00.HeatingRate, aod1_00.pressure)
gca().invert_yaxis()
xlabel('Heating Rate (K day-1)')
ylabel('Pressure (mb)')
title('Heating Rate')
legend(['0.0', '0.25', '0.5', '0.75', '1.0'], loc='best')
