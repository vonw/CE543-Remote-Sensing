# %% [markdown]
# # Mie Scattering

# %% [markdown]
# <i>© Von P. Walden, Washington State University</i>

# %% [markdown]
# ## This notebook reproduces figures from Chapter 12 in Petty (2006) from section 12.3 - Scattering by Spheres - Mie Theory

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/vonw/anaconda3/envs/mie/lib/python3.7/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['show', 'figure']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
from bokeh.plotting import figure, show, output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2120">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Initialization

# %%
# Obtained from https://github.com/jleinonen/pymiecoated
from miepython import mie

# %% [markdown]
# ### Figure 12.4

# %%
# Complex index of refraction
m = complex(1.33)       # Real part only; no absorption

# Vector of size parameters
X = arange(0.1,100,0.1)

Qe = array([])
Qs = array([])
Qa = array([])

for x in X:
    qext, qsca, qback, g = mie(m,x)
    Qe  = append(Qe, qext)
    Qs  = append(Qs, qsca)
    Qa  = append(Qa, qext-qsca)

p = figure(plot_width=900,plot_height=500)
p.line(X,Qe)
p.xaxis.axis_label = 'Size parameter, x = 2*pi*r / wavelength'
p.yaxis.axis_label = 'Qext'
#title('Extinction Efficiency (m=1.33)')

show(p)
# Out:
#   <div class="bk-root" id="b25c2223-a172-445a-be3c-42ce2d4f2c03" data-root-id="2121"></div>

# %%
p = figure(plot_width=900, 
           plot_height=500, 
           x_range=[0,20], 
           y_range=[0,4],
           title='Extinction Efficiency (m=1.33)')
p.line(X,Qe)
#p.axis([0, 20, 0, 4])
p.xaxis.axis_label = 'Size parameter, x = 2*pi*r / wavelength'
p.yaxis.axis_label = 'Qext'

show(p)
# Out:
#   <div class="bk-root" id="42d7cfe5-b124-4c18-a368-ce52580451de" data-root-id="2292"></div>

# %%
# Rayleigh Scattering; Qs = Qe, since the spheres are non-absorbing.
Qs_r = (8./3.) * X**4 * abs ( (m**2 - 1) / (m**2 + 2) )**2       # Eq. 12.13


p = figure(plot_width=900, 
           plot_height=500, 
           x_range=[0,0.8], 
           y_range=[0,0.05],
           title='Extinction and Scattering Efficiencies (m=1.33)')
p.line(X, Qe,   color='blue', legend="Qext")
p.line(X, Qs_r, color='red',  legend='Qsca')
p.xaxis.axis_label = 'Size parameter, x = 2*pi*r / wavelength'
p.yaxis.axis_label = 'Qext, Qsca'
p.legend.location  = 'top_left'

show(p)
# Out:
#   <div class="bk-root" id="551b38c7-38c4-4fd9-a426-18aa525b0006" data-root-id="2915"></div>

# %% [markdown]
# ### Figure 12.5

# %%
# Complex index of refraction
m = complex(1.33)       # Real part only; no absorption

# Vector of wavelengths
wv = arange(0.3,1.0,0.01)    # in microns

Qe_0_1 = array([])
Qe_0_3 = array([])
Qe_1 = array([])
Qe_10 = array([])


for w in wv:
    qext, qsca, qback, g = mie(m,2*pi*0.1/w)
    Qe_0_1 = append(Qe_0_1, qext)
    qext, qsca, qback, g = mie(m,2*pi*0.3/w)
    Qe_0_3 = append(Qe_0_3, qext)
    qext, qsca, qback, g = mie(m,2*pi*1.0/w)
    Qe_1 = append(Qe_1, qext)
    qext, qsca, qback, g = mie(m,2*pi*10.0/w)
    Qe_10 = append(Qe_10, qext)

# %%
p = figure(plot_width=900, 
           plot_height=500, 
           x_range=[0.3,1.0], 
           y_range=[0,4],
           title='Extinction Efficiency (m=1.33)')
p.line(wv,Qe_0_1, color='blue',  legend='r = 0.1 um')
p.line(wv,Qe_0_3, color='green', legend='r = 0.3 um')
p.line(wv,Qe_1,   color='red',   legend='r = 1 um')
p.line(wv,Qe_10,  color='cyan',  legend='r = 10 um')
p.xaxis.axis_label = 'Wavelength (um)'
p.yaxis.axis_label = 'Qext'

show(p)
# Out:
#   <div class="bk-root" id="147fa43d-7150-4097-a726-2a9727537d7a" data-root-id="1354"></div>

# %% [markdown]
# ### Figure 12.6

# %%
# Complex index of refraction
m1 = complex(1.33)       # Real part only; no absorption
m2 = complex(1.33,0.001)
m3 = complex(1.33,0.01)
m4 = complex(1.33,0.1)
m5 = complex(1.33,1.0)

# Vector of size parameters
X = arange(0.1,50,0.1)

Qe1 = array([])
Qs1 = array([])
Qa1 = array([])
g1  = array([])
w1  = array([])
Qe2 = array([])
Qs2 = array([])
Qa2 = array([])
g2  = array([])
w2  = array([])
Qe3 = array([])
Qs3 = array([])
Qa3 = array([])
g3  = array([])
w3  = array([])
Qe4 = array([])
Qs4 = array([])
Qa4 = array([])
g4  = array([])
w4  = array([])
Qe5 = array([])
Qs5 = array([])
Qa5 = array([])
g5  = array([])
w5  = array([])

for x in X:
    qext, qsca, qback, g = mie(m1,x)
    Qe1  = append(Qe1, qext)
    Qs1  = append(Qs1, qsca)
    Qa1  = append(Qa1, qext-qsca)
    g1   = append(g1,  g)
    w1   = append(w1,qsca/qext)
    
    qext, qsca, qback, g = mie(m2,x)
    Qe2  = append(Qe2, qext)
    Qs2  = append(Qs2, qsca)
    Qa2  = append(Qa2, qext-qsca)
    g2   = append(g2,  g)
    w2   = append(w2,qsca/qext)

    
    qext, qsca, qback, g = mie(m3,x)
    Qe3  = append(Qe3, qext)
    Qs3  = append(Qs3, qsca)
    Qa3  = append(Qa3, qext-qsca)
    g3   = append(g3,  g)
    w3   = append(w3,qsca/qext)

    
    qext, qsca, qback, g = mie(m4,x)
    Qe4  = append(Qe4, qext)
    Qs4  = append(Qs4, qsca)
    Qa4  = append(Qa4, qext-qsca)
    g4   = append(g4,  g)
    w4   = append(w4,qsca/qext)

    
    qext, qsca, qback, g = mie(m5,x)
    Qe5  = append(Qe5, qext)
    Qs5  = append(Qs5, qsca)
    Qa5  = append(Qa5, qext-qsca)
    g5   = append(g5,  g)
    w5   = append(w5,qsca/qext)

# %%
p = figure(plot_width=900, 
           plot_height=500, 
           x_range=[0,50], 
           y_range=[0,4],
           title='Extinction Efficiency')
p.line(X,Qe1, color='blue',  legend='m = 1.33')
p.line(X,Qe4, color='green', legend='m = 1.33 + 0.1i')
p.line(X,Qe5, color='red',   legend='m = 1.33 + 1.0i')
p.xaxis.axis_label = 'Size Parameter, X'
p.yaxis.axis_label = 'Qext'

show(p)
# Out:
#   <div class="bk-root" id="02ae488f-bbf5-467e-afae-2f2b9b526881" data-root-id="1990"></div>

# %%
p = figure(plot_width=900, 
           plot_height=500, 
           x_range=[0,50], 
           y_range=[0,2],
           title='Absorption Efficiency')
p.line(X, Qa2, color='blue', legend='m = 1.33 + 0.001i')
p.line(X, Qa3, color='green', legend='m = 1.33 + 0.01i')
p.line(X, Qa4, color='red', legend='m = 1.33 + 0.1i')
p.line(X, Qa5, color='cyan', legend='m = 1.33 + 1.0i')
p.xaxis.axis_label = 'Size Parameter, X'
p.yaxis.axis_label = 'Qabs'

show(p)
# Out:
#   <div class="bk-root" id="cc062f18-f882-4bdf-88a7-cf201ac75efd" data-root-id="2216"></div>

# %%
p = figure(plot_width=900, 
           plot_height=500, 
           x_range=[0,50], 
           y_range=[0,1],
           title='Single Scatter Albedo')
p.line(X,w2, color='blue', legend='m = 1.33 + 0.001i')
p.line(X,w3, color='green', legend='m = 1.33 + 0.01i')
p.line(X,w4, color='red', legend='m = 1.33 + 0.1i')
p.line(X,w5, color='cyan', legend='m = 1.33 + 1.0i')
p.xaxis.axis_label = 'Size Parameter, X'
p.yaxis.axis_label = 'omega'
show(p)
# Out:
#   <div class="bk-root" id="70705b84-5f10-447a-88ae-de857cd0d6f8" data-root-id="2486"></div>

# %%
p = figure(plot_width=900, 
           plot_height=500, 
           x_range=[0,50], 
           y_range=[0,1],
           title='Scattering Asymmetry Parameter')
p.line(X,g2, color='blue', legend='m = 1.33 + 0.001i')
p.line(X,g3, color='green', legend='m = 1.33 + 0.01i')
p.line(X,g4, color='red', legend='m = 1.33 + 0.1i')
p.line(X,g5, color='cyan', legend='m = 1.33 + 1.0i')
p.xaxis.axis_label = 'Size Parameter, X'
p.yaxis.axis_label = 'g'
show(p)
# Out:
#   <div class="bk-root" id="d4a58fcd-f6b7-4346-b8ed-c3c4894948fc" data-root-id="2770"></div>

# %% [markdown]
# ### Figure 12.7

# %%
m  = 1.33
x  = 10
us = arange(-1.,1.,0.001)
mie = Mie(x=x,m=m)

p = array([])

for u in us:
    S1,S2 = mie.S12(u)
    p = append(p, (1./mie.qsca()) * 0.5 * (abs(S1)**2 + abs(S2)**2) )
#    p = append(p, 0.5 * (abs(S1)**2 + abs(S2)**2) )

pl = figure(plot_width=900, 
           plot_height=500, 
           x_range=[0,180], 
           title='Scattering Asymmetry Parameter, (x=10, m=1.33)',
           y_axis_type='log')
pl.line(np.arccos(us)*180./pi,p)
pl.xaxis.axis_label = 'Scattering Angle'
pl.yaxis.axis_label = 'Scattering Phase Function, p'
show(pl)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="87d8efa8-fea0-4321-9d00-658e910d8965"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("87d8efa8-fea0-4321-9d00-658e910d8965");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '87d8efa8-fea0-4321-9d00-658e910d8965' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a52662bc-f586-4236-bbb3-bdb96d2754db":{"roots":{"references":[{"attributes":{"overlay":{"id":"35dc6f47-8b6d-43cf-98e1-c0aea89463c5","type":"BoxAnnotation"},"plot":{"id":"62e67837-e32f-4d22-9361-4d6e79493bd2","subtype":"Figure","type":"Plot"}},"id":"47d39de4-13c2-485d-95dc-9851f83e97d1","type":"BoxZoomTool"},{"attributes":{"below":[{"id":"ffb6e119-db35-4433-80f5-13a439822cb9","type":"LinearAxis"}],"left":[{"id":"c061aeb2-26f0-433d-a9fe-6a9f72d11bee","type":"LogAxis"}],"plot_height":500,"plot_width":900,"renderers":[{"id":"ffb6e119-db35-4433-80f5-13a439822cb9","type":"LinearAxis"},{"id":"0d7e87ff-c45a-4391-857a-4298c13bb30d","type":"Grid"},{"id":"c061aeb2-26f0-433d-a9fe-6a9f72d11bee","type":"LogAxis"},{"id":"c7602999-ddf1-4663-92b6-66b8e8ba8e0d","type":"Grid"},{"id":"35dc6f47-8b6d-43cf-98e1-c0aea89463c5","type":"BoxAnnotation"},{"id":"0e7a5a05-aef3-4774-a57d-f51bee94595e","type":"GlyphRenderer"}],"title":{"id":"5027a7f2-a8a0-424a-be81-fb2fe5d9f4b9","type":"Title"},"tool_events":{"id":"4416f984-365a-498d-8561-3556bdb02761","type":"ToolEvents"},"toolbar":{"id":"c202bf52-3323-41fd-88e8-92dfab23a19a","type":"Toolbar"},"x_range":{"id":"47665fe1-781f-4add-9257-3ca9d78f0d5d","type":"Range1d"},"y_mapper_type":"log","y_range":{"id":"c246a483-2b62-4eb4-9693-73ea91550b20","type":"DataRange1d"}},"id":"62e67837-e32f-4d22-9361-4d6e79493bd2","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null},"id":"c246a483-2b62-4eb4-9693-73ea91550b20","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"dd112a87-c0ea-4d23-b73e-8d416d48196a","type":"PanTool"},{"id":"3f593841-79bb-4dd2-84f5-9dc4cdf547f3","type":"WheelZoomTool"},{"id":"47d39de4-13c2-485d-95dc-9851f83e97d1","type":"BoxZoomTool"},{"id":"54cda39c-87e1-40ba-97ce-751a7021eea5","type":"SaveTool"},{"id":"8e9f2104-0131-4a8a-b92f-6b720ab3ecb2","type":"ResetTool"},{"id":"69cdb158-e4ab-4d27-bf06-eeceaa29d500","type":"HelpTool"}]},"id":"c202bf52-3323-41fd-88e8-92dfab23a19a","type":"Toolbar"},{"attributes":{"axis_label":"Scattering Phase Function, p","formatter":{"id":"d28819d1-a0f4-4fdc-a0aa-a24ccc929208","type":"LogTickFormatter"},"plot":{"id":"62e67837-e32f-4d22-9361-4d6e79493bd2","subtype":"Figure","type":"Plot"},"ticker":{"id":"9f31ad67-1c25-4453-9d17-dda0c6723ec1","type":"LogTicker"}},"id":"c061aeb2-26f0-433d-a9fe-6a9f72d11bee","type":"LogAxis"},{"attributes":{},"id":"4416f984-365a-498d-8561-3556bdb02761","type":"ToolEvents"},{"attributes":{"axis_label":"Scattering Angle","formatter":{"id":"5e0e08c1-6163-457d-a59d-3d2aa4895986","type":"BasicTickFormatter"},"plot":{"id":"62e67837-e32f-4d22-9361-4d6e79493bd2","subtype":"Figure","type":"Plot"},"ticker":{"id":"533209dc-f1c8-4aef-804c-257f9cbc7863","type":"BasicTicker"}},"id":"ffb6e119-db35-4433-80f5-13a439822cb9","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"62e67837-e32f-4d22-9361-4d6e79493bd2","subtype":"Figure","type":"Plot"},"ticker":{"id":"9f31ad67-1c25-4453-9d17-dda0c6723ec1","type":"LogTicker"}},"id":"c7602999-ddf1-4663-92b6-66b8e8ba8e0d","type":"Grid"},{"attributes":{},"id":"5e0e08c1-6163-457d-a59d-3d2aa4895986","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"62e67837-e32f-4d22-9361-4d6e79493bd2","subtype":"Figure","type":"Plot"}},"id":"dd112a87-c0ea-4d23-b73e-8d416d48196a","type":"PanTool"},{"attributes":{"num_minor_ticks":10},"id":"9f31ad67-1c25-4453-9d17-dda0c6723ec1","type":"LogTicker"},{"attributes":{"plot":{"id":"62e67837-e32f-4d22-9361-4d6e79493bd2","subtype":"Figure","type":"Plot"}},"id":"69cdb158-e4ab-4d27-bf06-eeceaa29d500","type":"HelpTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"35dc6f47-8b6d-43cf-98e1-c0aea89463c5","type" ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[12]</strong>&gt;</code></p>
